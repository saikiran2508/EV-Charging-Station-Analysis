# %% [markdown]
# ### 1. API Request and saving the data

# %%
# Import the requests library
import os
from dotenv import load_dotenv
import requests

load_dotenv()

URL = "https://api.openchargemap.io/v3/poi/?"
params = {
    "output": "json",
    "countrycode": "HU",
    "maxresults": 1000,
    "key": "69ebdaac-23f2-470c-be6d-9dcea563e9df"
}

# Get the data from the API
try:
    response = requests.get(URL, params=params, timeout=10)
    response.raise_for_status()
except requests.exceptions.RequestException as e:
    print(f"API Error: {e}")
data = response.json()

# %%
# Convert to DataFrame and print columns
import pandas as pd
df = pd.json_normalize(data) 
print(df.columns.tolist())
# Out:
# ['UserComments', 'PercentageSimilarity', 'MediaItems', 'IsRecentlyVerified', 'DateLastVerified', 'ID', 'UUID', 'ParentChargePointID', 'DataProviderID', 'DataProvidersReference', 'OperatorID', 'OperatorsReference', 'UsageTypeID', 'UsageCost', 'Connections', 'NumberOfPoints', 'GeneralComments', 'DatePlanned', 'DateLastConfirmed', 'StatusTypeID', 'DateLastStatusUpdate', 'MetadataValues', 'DataQualityLevel', 'DateCreated', 'SubmissionStatusTypeID', 'DataProvider.WebsiteURL', 'DataProvider.Comments', 'DataProvider.DataProviderStatusType.IsProviderEnabled', 'DataProvider.DataProviderStatusType.ID', 'DataProvider.DataProviderStatusType.Title', 'DataProvider.IsRestrictedEdit', 'DataProvider.IsOpenDataLicensed', 'DataProvider.IsApprovedImport', 'DataProvider.License', 'DataProvider.DateLastImported', 'DataProvider.ID', 'DataProvider.Title', 'OperatorInfo.WebsiteURL', 'OperatorInfo.Comments', 'OperatorInfo.PhonePrimaryContact', 'OperatorInfo.PhoneSecondaryContact', 'OperatorInfo.IsPrivateIndividual', 'OperatorInfo.AddressInfo', 'OperatorInfo.BookingURL', 'OperatorInfo.ContactEmail', 'OperatorInfo.FaultReportEmail', 'OperatorInfo.IsRestrictedEdit', 'OperatorInfo.ID', 'OperatorInfo.Title', 'UsageType.IsPayAtLocation', 'UsageType.IsMembershipRequired', 'UsageType.IsAccessKeyRequired', 'UsageType.ID', 'UsageType.Title', 'StatusType.IsOperational', 'StatusType.IsUserSelectable', 'StatusType.ID', 'StatusType.Title', 'SubmissionStatus.IsLive', 'SubmissionStatus.ID', 'SubmissionStatus.Title', 'AddressInfo.ID', 'AddressInfo.Title', 'AddressInfo.AddressLine1', 'AddressInfo.AddressLine2', 'AddressInfo.Town', 'AddressInfo.StateOrProvince', 'AddressInfo.Postcode', 'AddressInfo.CountryID', 'AddressInfo.Country.ISOCode', 'AddressInfo.Country.ContinentCode', 'AddressInfo.Country.ID', 'AddressInfo.Country.Title', 'AddressInfo.Latitude', 'AddressInfo.Longitude', 'AddressInfo.ContactTelephone1', 'AddressInfo.ContactTelephone2', 'AddressInfo.ContactEmail', 'AddressInfo.AccessComments', 'AddressInfo.RelatedURL', 'AddressInfo.Distance', 'AddressInfo.DistanceUnit', 'OperatorInfo']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 867 entries, 0 to 866
# Data columns (total 83 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   UserComments                                           166 non-null    object
#  1   PercentageSimilarity                                   0 non-null      object
#  2   MediaItems                                             307 non-null    object
#  3   IsRecentlyVerified                                     867 non-null    bool
#  4   DateLastVerified                                       867 non-null    object
#  5   ID                                                     867 non-null    int64
#  6   UUID                                                   867 non-null    object
#  7   ParentChargePointID                                    0 non-null      object
#  8   DataProviderID                                         867 non-null    int64
#  9   DataProvidersReference                                 0 non-null      object
#  10  OperatorID                                             855 non-null    float64
#  11  OperatorsReference                                     33 non-null     object
#  12  UsageTypeID                                            867 non-null    int64
#  13  UsageCost                                              638 non-null    object
#  14  Connections                                            867 non-null    object
#  15  NumberOfPoints                                         866 non-null    float64
#  16  GeneralComments                                        392 non-null    object
#  17  DatePlanned                                            0 non-null      object
#  18  DateLastConfirmed                                      0 non-null      object
#  19  StatusTypeID                                           867 non-null    int64
#  20  DateLastStatusUpdate                                   867 non-null    object
#  21  MetadataValues                                         0 non-null      object
#  22  DataQualityLevel                                       867 non-null    int64
#  23  DateCreated                                            867 non-null    object
#  24  SubmissionStatusTypeID                                 867 non-null    int64
#  25  DataProvider.WebsiteURL                                867 non-null    object
#  26  DataProvider.Comments                                  0 non-null      object
#  27  DataProvider.DataProviderStatusType.IsProviderEnabled  867 non-null    bool
#  28  DataProvider.DataProviderStatusType.ID                 867 non-null    int64
#  29  DataProvider.DataProviderStatusType.Title              867 non-null    object
#  30  DataProvider.IsRestrictedEdit                          867 non-null    bool
#  31  DataProvider.IsOpenDataLicensed                        867 non-null    bool
#  32  DataProvider.IsApprovedImport                          867 non-null    bool
#  33  DataProvider.License                                   867 non-null    object
#  34  DataProvider.DateLastImported                          0 non-null      object
#  35  DataProvider.ID                                        867 non-null    int64
#  36  DataProvider.Title                                     867 non-null    object
#  37  OperatorInfo.WebsiteURL                                611 non-null    object
#  38  OperatorInfo.Comments                                  193 non-null    object
#  39  OperatorInfo.PhonePrimaryContact                       33 non-null     object
#  40  OperatorInfo.PhoneSecondaryContact                     0 non-null      float64
#  41  OperatorInfo.IsPrivateIndividual                       791 non-null    object
#  42  OperatorInfo.AddressInfo                               0 non-null      float64
#  43  OperatorInfo.BookingURL                                2 non-null      object
#  44  OperatorInfo.ContactEmail                              54 non-null     object
#  45  OperatorInfo.FaultReportEmail                          12 non-null     object
#  46  OperatorInfo.IsRestrictedEdit                          609 non-null    object
#  47  OperatorInfo.ID                                        855 non-null    float64
#  48  OperatorInfo.Title                                     855 non-null    object
#  49  UsageType.IsPayAtLocation                              249 non-null    object
#  50  UsageType.IsMembershipRequired                         255 non-null    object
#  51  UsageType.IsAccessKeyRequired                          249 non-null    object
#  52  UsageType.ID                                           867 non-null    int64
#  53  UsageType.Title                                        867 non-null    object
#  54  StatusType.IsOperational                               867 non-null    bool
#  55  StatusType.IsUserSelectable                            867 non-null    bool
#  56  StatusType.ID                                          867 non-null    int64
#  57  StatusType.Title                                       867 non-null    object
#  58  SubmissionStatus.IsLive                                867 non-null    bool
#  59  SubmissionStatus.ID                                    867 non-null    int64
#  60  SubmissionStatus.Title                                 867 non-null    object
#  61  AddressInfo.ID                                         867 non-null    int64
#  62  AddressInfo.Title                                      867 non-null    object
#  63  AddressInfo.AddressLine1                               867 non-null    object
#  64  AddressInfo.AddressLine2                               112 non-null    object
#  65  AddressInfo.Town                                       859 non-null    object
#  66  AddressInfo.StateOrProvince                            600 non-null    object
#  67  AddressInfo.Postcode                                   766 non-null    object
#  68  AddressInfo.CountryID                                  867 non-null    int64
#  69  AddressInfo.Country.ISOCode                            867 non-null    object
#  70  AddressInfo.Country.ContinentCode                      867 non-null    object
#  71  AddressInfo.Country.ID                                 867 non-null    int64
#  72  AddressInfo.Country.Title                              867 non-null    object
#  73  AddressInfo.Latitude                                   867 non-null    float64
#  74  AddressInfo.Longitude                                  867 non-null    float64
#  75  AddressInfo.ContactTelephone1                          467 non-null    object
#  76  AddressInfo.ContactTelephone2                          96 non-null     object
#  77  AddressInfo.ContactEmail                               258 non-null    object
#  78  AddressInfo.AccessComments                             257 non-null    object
#  79  AddressInfo.RelatedURL                                 521 non-null    object
#  80  AddressInfo.Distance                                   0 non-null      object
#  81  AddressInfo.DistanceUnit                               867 non-null    int64
#  82  OperatorInfo                                           0 non-null      float64
# dtypes: bool(8), float64(8), int64(15), object(52)
# memory usage: 514.9+ KB

# %%
df.head()
# Out:
#                                         UserComments PercentageSimilarity  \
# 0                                               None                 None
# 1                                               None                 None
# 2                                               None                 None
# 3  [{'ID': 30601, 'ChargePointID': 457975, 'Comme...                 None
# 4                                               None                 None
#
#                                           MediaItems  IsRecentlyVerified  \
# 0  [{'ID': 47126, 'ChargePointID': 459919, 'ItemU...                True
# 1                                               None                True
# 2  [{'ID': 46927, 'ChargePointID': 458920, 'ItemU...                True
# 3  [{'ID': 46891, 'ChargePointID': 457975, 'ItemU...                True
# 4                                               None                True
#
#        DateLastVerified      ID                                  UUID  \
# 0  2025-07-21T09:31:00Z  459919  1EF09352-6313-4A73-84CF-64C4E4B70288
# 1  2025-07-05T05:19:00Z  459055  B167A383-ABAF-4DCF-8A68-8B3B8927D3E6
# 2  2025-06-25T11:27:00Z  458920  CCC4C1E9-681F-4536-A3BD-16F4002D2DF7
# 3  2025-06-25T14:54:00Z  457975  34AB33A5-4493-46A2-8620-6973ADEB3010
# 4  2025-06-16T19:34:00Z  313310  18DB6494-7E85-443E-9866-71BF17961E92
#
#   ParentChargePointID  DataProviderID DataProvidersReference  ...  \
# 0                None               1                   None  ...
# 1                None               1                   None  ...
# 2                None               1                   None  ...
# 3                None               1                   None  ...
# 4                None               1                   None  ...
#
#    AddressInfo.Latitude AddressInfo.Longitude  AddressInfo.ContactTelephone1  \
# 0             46.402560             20.356911                +36 30 461 2828
# 1             47.851568             20.145685                   +36302054126
# 2             47.246084             16.604407                +36 30 461 2828
# 3             47.792846             19.115667                           None
# 4             47.677106             19.667077                           None
#
#   AddressInfo.ContactTelephone2 AddressInfo.ContactEmail  \
# 0                          None                     None
# 1                  +36305011571                     None
# 2                          None                     None
# 3                          None                     None
# 4                          None                     None
#
#                           AddressInfo.AccessComments  \
# 0                                               None
# 1  For opening the gates please call +36305011571...
# 2                                               None
# 3                                               None
# 4                                               None
#
#          AddressInfo.RelatedURL AddressInfo.Distance AddressInfo.DistanceUnit  \
# 0           https://ev.curb.hu/                 None                        0
# 1          https://var-liget.hu                 None                        0
# 2  https://ev.curb.hu/CURB4022A                 None                        0
# 3                          None                 None                        0
# 4                          None                 None                        0
#
#    OperatorInfo
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 83 columns]

# %%
df.tail()
# Out:
#                                           UserComments PercentageSimilarity  \
# 862  [{'ID': 19624, 'ChargePointID': 31615, 'Commen...                 None
# 863  [{'ID': 4434, 'ChargePointID': 31613, 'Comment...                 None
# 864  [{'ID': 14622, 'ChargePointID': 31195, 'Commen...                 None
# 865  [{'ID': 4432, 'ChargePointID': 31194, 'Comment...                 None
# 866                                               None                 None
#
#                                             MediaItems  IsRecentlyVerified  \
# 862  [{'ID': 15612, 'ChargePointID': 31615, 'ItemUR...               False
# 863  [{'ID': 1311, 'ChargePointID': 31613, 'ItemURL...               False
# 864  [{'ID': 1275, 'ChargePointID': 31195, 'ItemURL...               False
# 865  [{'ID': 1427, 'ChargePointID': 31194, 'ItemURL...               False
# 866                                               None               False
#
#          DateLastVerified     ID                                  UUID  \
# 862  2024-02-05T09:45:00Z  31615  83CF29C7-AD32-49A3-BFD0-384D1DB8AAB1
# 863  2024-02-05T09:45:00Z  31613  C5D4CCDE-DBB9-4699-8F23-FE840471DDD3
# 864  2016-12-31T09:29:00Z  31195  BB97B029-6851-4F50-88D6-0C24E45059E7
# 865  2024-02-05T09:45:00Z  31194  953DF5FC-60E2-4911-8ABA-C73C9756A0F7
# 866  2020-01-05T13:56:00Z  23660  E31104D0-50F0-4F1A-84B6-B7745E00D62A
#
#     ParentChargePointID  DataProviderID DataProvidersReference  ...  \
# 862                None               1                   None  ...
# 863                None               1                   None  ...
# 864                None               1                   None  ...
# 865                None               1                   None  ...
# 866                None               1                   None  ...
#
#      AddressInfo.Latitude AddressInfo.Longitude  \
# 862             47.465555             19.023444
# 863             47.464205             19.144451
# 864             47.561702             19.053664
# 865             47.501086             19.047113
# 866             46.535289             21.252083
#
#      AddressInfo.ContactTelephone1 AddressInfo.ContactTelephone2  \
# 862                 +36 80 200 897                          None
# 863                 +36 80 200 897                          None
# 864                           None                          None
# 865                 +36 80 200 897                          None
# 866                   +36309609550                   +3666240011
#
#     AddressInfo.ContactEmail  \
# 862                     None
# 863                     None
# 864                     None
# 865                     None
# 866          info@dmotors.hu
#
#                             AddressInfo.AccessComments  \
# 862                                               None
# 863  A P+R parkoló sorompón belüli részén. Belépésk...
# 864                                               None
# 865  A töltőoszlop nem a két parkoló között középen...
# 866                                               None
#
#                              AddressInfo.RelatedURL AddressInfo.Distance  \
# 862  https://www.eon.hu/hu/e-mobilitas/driveon.html                 None
# 863  https://www.eon.hu/hu/e-mobilitas/driveon.html                 None
# 864                                            None                 None
# 865  https://www.eon.hu/hu/e-mobilitas/driveon.html                 None
# 866                           http://www.dmotors.hu                 None
#
#     AddressInfo.DistanceUnit  OperatorInfo
# 862                        0           NaN
# 863                        0           NaN
# 864                        0           NaN
# 865                        0           NaN
# 866                        0           NaN
#
# [5 rows x 83 columns]

# %%
# Save the data to a CSV file
df.to_csv('ev_charging_data.csv', index=False)
